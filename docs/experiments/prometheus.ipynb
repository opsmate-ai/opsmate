# %%
from opsmate.tools.prom import PrometheusTool

import os

# await init_table()

# dbconn = await aconn()

tool = PrometheusTool(
    natural_language_query="http request per seconds break down by path for the o11y demo app over the past 30mins"
)

await tool.run(context={
    "top_n": 10,
})

tool.time_series()
# Out:
# 2025-03-07 10:13:07 [info     ] datetime_extraction            text=past 30mins
# 2025-03-07 10:13:07 [info     ] running knowledge retrieval tool categories=[] llm_summary=False query=prometheus metrics for http requests per second by path top_n=10
# 2025-03-07 10:13:07 [info     ] running knowledge retrieval tool categories=[] llm_summary=False query=o11y demo app http metrics top_n=10
# Linear Dim set to: 96 for downcasting
# 2025-03-07 10:13:14 [info     ] reranked results               length=10
# 2025-03-07 10:13:14 [info     ] call completed                 function=opsmate.tools.knowledge_retrieval.__call__ time=6.523133993148804
# 2025-03-07 10:13:14 [info     ] reranked results               length=10
# 2025-03-07 10:13:14 [info     ] call completed                 function=opsmate.tools.knowledge_retrieval.__call__ time=6.918453931808472
# ...
