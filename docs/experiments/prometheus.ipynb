# %%
from opsmate.tools.prom import PrometheusTool

import os

# await init_table()

# dbconn = await aconn()

tool = PrometheusTool(
    natural_language_query="cpu usage break down by namespace over the past 2 hours"
)

await tool.run(context={
    "top_n": 10,
})

tool.time_series()
# Out:
# 2025-03-07 16:31:29 [info     ] datetime_extraction            text=past 2 hours
# 2025-03-07 16:31:29 [info     ] running knowledge retrieval tool categories=[] llm_summary=False query=prometheus cpu usage metrics namespace top_n=10
# 2025-03-07 16:31:32 [info     ] reranked results               length=10
# 2025-03-07 16:31:32 [info     ] call completed                 function=opsmate.tools.knowledge_retrieval.__call__ time=3.3806796073913574
# 2025-03-07 16:31:38 [info     ] plotting time series           query=sum(rate(container_cpu_usage_seconds_total{namespace!=""}[2m])) by (namespace)
